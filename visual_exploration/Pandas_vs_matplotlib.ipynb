# %% [markdown]
# # Plotting methods
# For publication and presentation, please do not use pyplot.
# Unless for marketing team for more detailed graphic charts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('heart.csv')
df.head(2)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1

# %%
fig, axes = plt.subplots(ncols=2)
df.plot.scatter(x='age', y='chol', ax=axes[0])
df.plot.scatter(x='age', y='trestbps', ax=axes[1])
fig.tight_layout();

# %%
fig2 = axes[0].get_figure()

# %%
fig2

# %%
fig2.savefig('plots', bbox_inches='tight', transparent=True)

# %%
with plt.style.context('default'):
    fig, axes = plt.subplots(ncols=3, sharey=True,
                            gridspec_kw={'width_ratios': [2,1,1], 'wspace': 0})
    y = 'age'
    xs = ['chol','trestbps','thalach']
    for x, ax in zip(xs, axes):
        ax.scatter(df[x], df[y])
        ax.set_xlabel(x)
        ax.set_ylabel(y)
    axes[0].set_ylabel(y)
    fig.savefig('output.pdf', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## Recap
# - Pandas is great for quickly plots
# - Maplotlib is more verbose, but has more control
# - You can mix and match
