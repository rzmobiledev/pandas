# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'AB_NYC_2019.csv')
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
df['host_name'].head(3)
# Out:
# 0         John
# 1     Jennifer
# 2    Elisabeth
# Name: host_name, dtype: object

# %%
df[['host_name', 'neighbourhood_group']].head(3)
# Out:
#    host_name neighbourhood_group
# 0       John            Brooklyn
# 1   Jennifer           Manhattan
# 2  Elisabeth           Manhattan

# %%
df[df['host_name'] == 'Taz']
# Out:
#              id                                               name   host_id  \
# 31463  24491624           43rd Street=TIME SQUARE\nPRIVATE BEDROOM  30985759
# 31517  24539281             43rd Street “TIME SQUARE”\nSingle bed.  30985759
# 37598  29827403  “TIME SQUARE” 43rd Street\nBig Bedroom on 1st ...  30985759
# 37615  29831106  TIME SQUARE” 43rd street\nPrivate room on 1st ...  30985759
# 37795  29929331               “TIME SQUARE” 43rd street SINGLE BED  30985759
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 31463       Taz           Manhattan  Hell's Kitchen  40.75780  -73.99211
# 31517       Taz           Manhattan  Hell's Kitchen  40.75792  -73.99172
# 37598       Taz           Manhattan  Hell's Kitchen  40.75988  -73.99123
# 37615       Taz           Manhattan  Hell's Kitchen  40.75938  -73.98986
# ...

# %%
quick_and_cheap = df[(df.price < 100) & (df.minimum_nights < 3)]
quick_and_cheap.head()
# Out:
#       id                                              name  host_id  \
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 11  5441                   Central Manhattan/near Broadway     7989
# 13  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 3   LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 7      Shunichi           Manhattan   Hell's Kitchen  40.76489  -73.98493
# 8     MaryEllen           Manhattan  Upper West Side  40.80178  -73.96723
# 11         Kate           Manhattan   Hell's Kitchen  40.76076  -73.98867
# 13      Claudio           Manhattan  Upper West Side  40.79826  -73.96113
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
review_consistent = df[(df.reviews_per_month > 3) & (df.number_of_reviews > 50)]
review_consistent.head()
# Out:
#        id                                             name  host_id  \
# 3    3831                  Cozy Entire Floor of Brownstone     4869
# 7    5178                 Large Furnished Room Near B'way      8967
# 18   7726  Hip Historic Brownstone Apartment with Backyard    20950
# 67  16580              Sunny, Modern room in East Village!    64442
# 91  20734              Spacious Prospect Heights Apartment    78460
#
#            host_name neighbourhood_group     neighbourhood  latitude  \
# 3        LisaRoxanne            Brooklyn      Clinton Hill  40.68514
# 7           Shunichi           Manhattan    Hell's Kitchen  40.76489
# 18  Adam And Charity            Brooklyn     Crown Heights  40.67592
# 67              Reka           Manhattan      East Village  40.72649
# 91    Sean & Lynette            Brooklyn  Prospect Heights  40.68233
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
inconsistent_review = df[~(df.reviews_per_month < 3) & (df.number_of_reviews > 50)]
inconsistent_review.shape
# Out:
# (3015, 16)

# %%
inconsistent_review.head(2)
# Out:
#      id                              name  host_id    host_name  \
# 3  3831   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 7  5178  Large Furnished Room Near B'way      8967     Shunichi
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn    Clinton Hill  40.68514  -73.95976  Entire home/apt
# 7           Manhattan  Hell's Kitchen  40.76489  -73.98493     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3     89               1                270  2019-07-05               4.64
# 7     79               2                430  2019-06-24               3.47
#
#    calculated_host_listings_count  availability_365
# 3                               1               194
# 7                               1               220

# %%
mask = (df.reviews_per_month < 3) & (df.number_of_reviews > 50)
df.loc[mask, ['name', 'host_id', 'host_name', 'price']].head(3)
# Out:
#                                         name  host_id  host_name  price
# 5  Large Cozy 1 BR Apartment In Midtown East     7322      Chris    200
# 8         Cozy Clean Guest Room - Family Apt     7490  MaryEllen     79
# 9         Cute & Cozy Lower East Side 1 bdrm     7549        Ben    150

# %%
df.loc[3, 'name'] = 'rizal safril'

# %%
df.loc[3, 'name']
# Out:
# 'rizal safril'

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                                      rizal safril     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.iloc[1, 3:5]
# Out:
# host_name               Jennifer
# neighbourhood_group    Manhattan
# Name: 1, dtype: object

# %%
df.loc[(df.price == df.price.max()), ['name','price']]
# Out:
#                                                   name  price
# 9151               Furnished room in Astoria apartment  10000
# 17692  Luxury 1 bedroom apt. -stunning Manhattan views  10000
# 29238                              1-BR Lincoln Center  10000

# %%
df[(df.name == 'rizal safril')]
# Out:
#      id          name  host_id    host_name neighbourhood_group neighbourhood  \
# 3  3831  rizal safril     4869  LisaRoxanne            Brooklyn  Clinton Hill
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 3  40.68514  -73.95976  Entire home/apt     89               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 3                270  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 3                               1               194

# %%
df.loc[(df.name == 'rizal safril')]
# Out:
#      id          name  host_id    host_name neighbourhood_group neighbourhood  \
# 3  3831  rizal safril     4869  LisaRoxanne            Brooklyn  Clinton Hill
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 3  40.68514  -73.95976  Entire home/apt     89               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 3                270  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 3                               1               194

# %%
df.query('name == "rizal safril"')
# Out:
#      id          name  host_id    host_name neighbourhood_group neighbourhood  \
# 3  3831  rizal safril     4869  LisaRoxanne            Brooklyn  Clinton Hill
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 3  40.68514  -73.95976  Entire home/apt     89               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 3                270  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 3                               1               194
